# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime as dt
import yfinance as yf

# %%
data = pd.read_csv('2330.csv')
data
# Out:
#             Date   Open   High    Low  Close   Adj Close    Volume     PE
# 0       2019/1/2  226.5  226.5  219.0  219.5  192.673233  32900482  16.24
# 1       2019/1/3  214.0  218.0  214.0  215.5  189.162109  34087620  15.94
# 2       2019/1/4  211.5  211.5  206.5  208.0  182.578751  65943521  15.38
# 3       2019/1/7  212.0  214.0  211.0  213.0  186.967667  35442176  15.75
# 4       2019/1/8  212.0  212.5  210.0  211.0  185.212067  22694481  15.61
# ...          ...    ...    ...    ...    ...         ...       ...    ...
# 1188  2023/11/24  577.0  578.0  574.0  575.0  575.000000  10058969  16.65
# 1189  2023/11/27  573.0  577.0  568.0  568.0  568.000000  18528520  16.44
# 1190  2023/11/28  565.0  576.0  565.0  575.0  575.000000  26343906  16.65
# 1191  2023/11/29  578.0  579.0  570.0  574.0  574.000000  24868842  16.62
# 1192  2023/11/30  576.0  577.0  570.0  577.0  577.000000  47192647  16.71
#
# [1193 rows x 8 columns]

# %%
data.plot(x='Date', y='PE', figsize=(20, 10), grid=True, title='2330 PE Ratio');
